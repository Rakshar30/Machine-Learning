# %%
import numpy as np
import matplotlib.pyplot as plt
def local_regression(x0, X, Y, tau):
    x0 = [1, x0]
    X = [[1, i] for i in X]
    X = np.asarray(X)
    W=np.diag(np.exp(-np.sum((X-x0)**2,axis=1)/(2*tau*tau)))
    beta = np.linalg.pinv(X.T@ W @ X)@X.T@ W @Y
    y_pred=np.dot(beta,x0)
    return y_pred
def draw(tau):
    prediction = [local_regression(x0, X, Y, tau) for x0 in domain]
    plt.plot(X, Y, 'o', color = 'black')
    plt.plot(domain, prediction, color = 'red')
    plt.show()
X = np.linspace(-3, 3, num = 100)
domain = X
Y = np.log(np.abs(X ** 2 - 1)+ .5)
print("X values:",X)
print("Y values:",Y)
print("\n Regression Line Fit for different values of Tau- 10,0.1,0.01,0.001")
draw(10)
draw(0.1)
draw(0.01)
draw(0.001)
# Out:
# X values: [-3.         -2.93939394 -2.87878788 -2.81818182 -2.75757576 -2.6969697
#  -2.63636364 -2.57575758 -2.51515152 -2.45454545 -2.39393939 -2.33333333
#  -2.27272727 -2.21212121 -2.15151515 -2.09090909 -2.03030303 -1.96969697
#  -1.90909091 -1.84848485 -1.78787879 -1.72727273 -1.66666667 -1.60606061
#  -1.54545455 -1.48484848 -1.42424242 -1.36363636 -1.3030303  -1.24242424
#  -1.18181818 -1.12121212 -1.06060606 -1.         -0.93939394 -0.87878788
#  -0.81818182 -0.75757576 -0.6969697  -0.63636364 -0.57575758 -0.51515152
#  -0.45454545 -0.39393939 -0.33333333 -0.27272727 -0.21212121 -0.15151515
#  -0.09090909 -0.03030303  0.03030303  0.09090909  0.15151515  0.21212121
#   0.27272727  0.33333333  0.39393939  0.45454545  0.51515152  0.57575758
#   0.63636364  0.6969697   0.75757576  0.81818182  0.87878788  0.93939394
#   1.          1.06060606  1.12121212  1.18181818  1.24242424  1.3030303
#   1.36363636  1.42424242  1.48484848  1.54545455  1.60606061  1.66666667
#   1.72727273  1.78787879  1.84848485  1.90909091  1.96969697  2.03030303
#   2.09090909  2.15151515  2.21212121  2.27272727  2.33333333  2.39393939
#   2.45454545  2.51515152  2.57575758  2.63636364  2.6969697   2.75757576
#   2.81818182  2.87878788  2.93939394  3.        ]
# Y values: [ 2.14006616  2.09679469  2.05250957  2.00715962  1.96068954  1.91303943
#   1.86414419  1.81393299  1.76232845  1.70924585  1.65459211  1.59826461
#   1.54014984  1.48012168  1.41803947  1.35374556  1.28706236  1.21778877
#   1.14569563  1.07052012  0.99195855  0.90965721  0.82320031  0.73209414
#   0.63574566  0.53343315  0.42426493  0.30712002  0.18055998  0.04269352
#  -0.10904037 -0.27823798 -0.4701873  -0.69314718 -0.48201301 -0.31782262
#  -0.18563282 -0.07679577  0.0141329   0.0907921   0.15572363  0.21076235
#   0.25726546  0.29625404  0.32850407  0.35460669  0.37500906  0.39004222
#   0.39994023  0.40485274  0.40485274  0.39994023  0.39004222  0.37500906
#   0.35460669  0.32850407  0.29625404  0.25726546  0.21076235  0.15572363
#   0.0907921   0.0141329  -0.07679577 -0.18563282 -0.31782262 -0.48201301
#  -0.69314718 -0.4701873  -0.27823798 -0.10904037  0.04269352  0.18055998
#   0.30712002  0.42426493  0.53343315  0.63574566  0.73209414  0.82320031
#   0.90965721  0.99195855  1.07052012  1.14569563  1.21778877  1.28706236
#   1.35374556  1.41803947  1.48012168  1.54014984  1.59826461  1.65459211
#   1.70924585  1.76232845  1.81393299  1.86414419  1.91303943  1.96068954
#   2.00715962  2.05250957  2.09679469  2.14006616]
#
#  Regression Line Fit for different values of Tau- 10,0.1,0.01,0.001
